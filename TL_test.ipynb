# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Activation, Dropout,Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D, Lambda, Input, AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from keras.callbacks import ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os
from random import randint
from sklearn.utils import shuffle

# %%
def get_images(directory):
    Images = []
    Labels = []  # 0 for Building , 1 for forest, 2 for glacier, 3 for mountain, 4 for Sea , 5 for Street
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'Anger': #Folder contain Glacier Images get the '2' class label.
            label = 2
        elif labels == 'Disgust':
            label = 4
        elif labels == 'Fear':
            label = 0
        elif labels == 'Happiness':
            label = 1
        elif labels == 'Neutral':
            label = 5
        elif labels == 'Sadness':
            label = 3
        elif labels == 'Surprise':
            label = 6    
        
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {2:'Anger', 4:'Disgust', 0:'Fear', 1:'Happiness', 5:'Neutral', 3:'Sadness', 6:'Surprise'}
    
    return labels[class_code]

# %%
Images, Labels = get_images('./dataset/train/') #Extract the training images from the folders.

data = np.array(Images) / 255.0 #converting the list of images to numpy array.
labels = np.array(Labels)

# %%
#np.savez_compressed('imageclassification2',x=data, y=labels)

# %%
# 이방식을쓰니 컴퓨터 메모리를 너무많이잡아먹는다
# 어레이저장파일을 바로로드해서 메모리를 많이 잡아먹는건 단순 속도가 빨라서 그런거였다.
# 내 pc의 메모리가 부족해서 일어난 현상
#imagesavez = np.load('./imageclassification2.npz')
#Data = imagesavez['x']
#Labels = imagesavez['y']

# %%
print("Shape of Images:",data.shape)
print("Shape of Labels:",labels.shape)
# Out:
# Shape of Images: (324, 150, 150, 3)
# Shape of Labels: (324,)

# %%
from matplotlib import pyplot as plt
f,ax = plt.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(data))
        ax[i,j].imshow(data[rnd_number])
        ax[i,j].set_title(get_classlabel(labels[rnd_number]))
        ax[i,j].axis('off')

# %%
# 초기학습률, epoch, batch size 설정
INIT_LR = 1e-3
EPOCHS = 100
BS = 8

# %%
labels
# Out:
# array([4, 3, 2, 4, 2, 1, 1, 4, 0, 4, 0, 3, 6, 0, 1, 3, 5, 1, 5, 0, 1, 5,
#        1, 3, 1, 5, 0, 2, 3, 2, 3, 6, 6, 0, 4, 2, 1, 3, 0, 4, 0, 0, 1, 6,
#        0, 1, 4, 0, 5, 3, 6, 0, 5, 1, 5, 0, 1, 1, 0, 6, 1, 1, 3, 3, 0, 4,
#        2, 5, 0, 6, 2, 0, 0, 6, 0, 4, 1, 2, 1, 6, 4, 1, 0, 0, 3, 5, 3, 3,
#        0, 1, 6, 2, 3, 6, 1, 6, 3, 3, 6, 5, 4, 1, 0, 3, 1, 6, 2, 5, 2, 3,
#        1, 0, 1, 4, 4, 3, 3, 3, 3, 0, 6, 1, 3, 5, 1, 6, 1, 6, 2, 2, 1, 1,
#        3, 3, 6, 1, 3, 0, 6, 5, 0, 5, 6, 2, 6, 6, 3, 4, 2, 6, 5, 6, 3, 5,
#        1, 1, 6, 5, 1, 1, 2, 1, 3, 4, 0, 1, 4, 0, 0, 4, 1, 4, 4, 0, 0, 5,
#        0, 5, 5, 5, 6, 3, 2, 4, 3, 0, 6, 5, 2, 0, 2, 4, 5, 3, 0, 6, 1, 0,
#        3, 2, 5, 6, 3, 3, 2, 0, 6, 6, 6, 6, 1, 3, 6, 3, 3, 3, 6, 5, 0, 0,
#        6, 4, 1, 1, 1, 3, 2, 6, 2, 6, 6, 1, 1, 3, 2, 0, 6, 2, 0, 5, 4, 0,
#        2, 0, 0, 3, 3, 5, 5, 6, 3, 0, 2, 4, 5, 3, 6, 4, 3, 2, 5, 1, 5, 5,
#        2, 0, 5, 3, 6, 4, 4, 1, 1, 0, 6, 5, 3, 6, 3, 1, 5, 1, 6, 2, 4, 3,
#        6, 4, 1, 0, 6, 2, 3, 1, 1, 5, 5, 2, 6, 6, 4, 5, 6, 6, 0, 3, 0, 3,
#        6, 1, 6, 0, 0, 5, 1, 1, 6, 5, 3, 3, 0, 4, 0, 4])

# %%
# labels 원핫 인코딩
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)
# 훈련데이터 테스트데이터 나누기 8:2
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, random_state=42)
# 훈련데이터 augmentation 객체 초기화
trainAug = ImageDataGenerator(rotation_range=15, fill_mode="nearest")

# %% [markdown]
# - train_test_split을 할때 원본 그대로 진행했을시 메모리 에러가 나서 10000개로 줄여주었다

# %%
# VGG16 모델 불러오기, fc계층 False설정, input_tensor설정(input_tensor크기), (분류기)include_top 이 True일 경우 이미지 크기는 사전학습된 모델의 값으로 고정되므로 input_tensor로 변경할 수 없다.
baseModel = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=(150, 150, 3)))
# 베이스모델의 top에 놓여질 head 구성
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.6)(headModel)
headModel = Dense(7, activation="softmax")(headModel)
# 헤드 FC모델을 기본 모델 위에 배치 ( 이것이 우리가 훈련할 실제 모델이 됩니다.)
model = Model(inputs=baseModel.input, outputs=headModel)
# 기본 모델의 모든 레이어를 반복하고 고정하여 첫 번째 트레이닝 프로세스 중에 업데이트되지 않도록 합니다.
for layer in baseModel.layers:
    layer.trainable = False

# %%
# 모델을 컴파일
print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# 학습 진행
print("[INFO] training head...")
H = model.fit_generator(
    trainAug.flow(trainX, trainY, batch_size=BS),
    steps_per_epoch=len(trainX) // BS,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BS,
    epochs=EPOCHS)
# Out:
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/100
# <ipython-input-14-14a65c6e8f8d>:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   H = model.fit_generator(
# 32/32 [==============================] - 2s 34ms/step - loss: 0.3914 - accuracy: 0.8685 - val_loss: 0.7126 - val_accuracy: 0.7538
# Epoch 2/100
# 32/32 [==============================] - 1s 28ms/step - loss: 0.3895 - accuracy: 0.8685 - val_loss: 0.7084 - val_accuracy: 0.7385
# Epoch 3/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3511 - accuracy: 0.8884 - val_loss: 0.7436 - val_accuracy: 0.8154
# Epoch 4/100
# 32/32 [==============================] - 1s 28ms/step - loss: 0.3633 - accuracy: 0.8884 - val_loss: 0.7687 - val_accuracy: 0.7538
# Epoch 5/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3549 - accuracy: 0.8789 - val_loss: 0.7257 - val_accuracy: 0.7692
# Epoch 6/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3525 - accuracy: 0.8725 - val_loss: 0.7344 - val_accuracy: 0.7846
# Epoch 7/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3737 - accuracy: 0.8845 - val_loss: 0.7507 - val_accuracy: 0.7538
# Epoch 8/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3555 - accuracy: 0.9004 - val_loss: 0.7687 - val_accuracy: 0.7692
# Epoch 9/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3205 - accuracy: 0.9044 - val_loss: 0.7403 - val_accuracy: 0.7538
# Epoch 10/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3577 - accuracy: 0.8924 - val_loss: 0.6785 - val_accuracy: 0.8000
# Epoch 11/100
# 32/32 [==============================] - 1s 28ms/step - loss: 0.3273 - accuracy: 0.8765 - val_loss: 0.7751 - val_accuracy: 0.7846
# Epoch 12/100
# 32/32 [==============================] - 1s 28ms/step - loss: 0.3776 - accuracy: 0.8845 - val_loss: 0.7248 - val_accuracy: 0.7692
# Epoch 13/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3397 - accuracy: 0.8964 - val_loss: 0.7382 - val_accuracy: 0.7846
# Epoch 14/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3318 - accuracy: 0.8884 - val_loss: 0.7189 - val_accuracy: 0.7846
# Epoch 15/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.3024 - accuracy: 0.9004 - val_loss: 0.7393 - val_accuracy: 0.7538
# Epoch 16/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.2814 - accuracy: 0.8884 - val_loss: 0.7744 - val_accuracy: 0.7846
# Epoch 17/100
# 32/32 [==============================] - 1s 28ms/step - loss: 0.3202 - accuracy: 0.8884 - val_loss: 0.7344 - val_accuracy: 0.7692
# Epoch 18/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1997 - accuracy: 0.9402 - val_loss: 0.7789 - val_accuracy: 0.7692
# Epoch 59/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1855 - accuracy: 0.9402 - val_loss: 0.7732 - val_accuracy: 0.7846
# Epoch 60/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1777 - accuracy: 0.9531 - val_loss: 0.8388 - val_accuracy: 0.7538
# Epoch 61/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1711 - accuracy: 0.9323 - val_loss: 0.8447 - val_accuracy: 0.7692
# Epoch 62/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.2491 - accuracy: 0.9044 - val_loss: 0.7932 - val_accuracy: 0.7846
# Epoch 63/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.2364 - accuracy: 0.9323 - val_loss: 0.7605 - val_accuracy: 0.8000
# Epoch 64/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.2173 - accuracy: 0.9243 - val_loss: 0.8361 - val_accuracy: 0.7538
# Epoch 65/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.2261 - accuracy: 0.9283 - val_loss: 0.8010 - val_accuracy: 0.7692
# Epoch 66/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.2454 - accuracy: 0.9363 - val_loss: 0.8117 - val_accuracy: 0.8000
# Epoch 67/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.2024 - accuracy: 0.9402 - val_loss: 0.8274 - val_accuracy: 0.7846
# Epoch 68/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1352 - accuracy: 0.9562 - val_loss: 0.8858 - val_accuracy: 0.7846
# Epoch 69/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1762 - accuracy: 0.9243 - val_loss: 0.8254 - val_accuracy: 0.7692
# Epoch 70/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1992 - accuracy: 0.9323 - val_loss: 0.8709 - val_accuracy: 0.7692
# Epoch 71/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1888 - accuracy: 0.9363 - val_loss: 0.8119 - val_accuracy: 0.7692
# Epoch 72/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1582 - accuracy: 0.9562 - val_loss: 0.8458 - val_accuracy: 0.7846
# Epoch 73/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1619 - accuracy: 0.9442 - val_loss: 0.8480 - val_accuracy: 0.8000
# Epoch 74/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1634 - accuracy: 0.9522 - val_loss: 0.8798 - val_accuracy: 0.7846
# Epoch 75/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1306 - accuracy: 0.9562 - val_loss: 0.8448 - val_accuracy: 0.7385
# Epoch 76/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1745 - accuracy: 0.9323 - val_loss: 0.8590 - val_accuracy: 0.7846
# Epoch 77/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1740 - accuracy: 0.9363 - val_loss: 0.8477 - val_accuracy: 0.7846
# Epoch 78/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1999 - accuracy: 0.9283 - val_loss: 0.8946 - val_accuracy: 0.7692
# Epoch 79/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1742 - accuracy: 0.9363 - val_loss: 0.8776 - val_accuracy: 0.7692
# Epoch 80/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1463 - accuracy: 0.9522 - val_loss: 0.8635 - val_accuracy: 0.7846
# Epoch 81/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1537 - accuracy: 0.9402 - val_loss: 0.9188 - val_accuracy: 0.7692
# Epoch 82/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1976 - accuracy: 0.9283 - val_loss: 0.9354 - val_accuracy: 0.7538
# Epoch 83/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1497 - accuracy: 0.9681 - val_loss: 0.8675 - val_accuracy: 0.7846
# Epoch 84/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1657 - accuracy: 0.9402 - val_loss: 0.8684 - val_accuracy: 0.7692
# Epoch 85/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1894 - accuracy: 0.9402 - val_loss: 0.8559 - val_accuracy: 0.7846
# Epoch 86/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1762 - accuracy: 0.9402 - val_loss: 0.7924 - val_accuracy: 0.7846
# Epoch 87/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1692 - accuracy: 0.9562 - val_loss: 0.8526 - val_accuracy: 0.7846
# Epoch 88/100
# 32/32 [==============================] - 1s 32ms/step - loss: 0.1953 - accuracy: 0.9163 - val_loss: 0.8157 - val_accuracy: 0.8000
# Epoch 89/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1590 - accuracy: 0.9562 - val_loss: 0.8251 - val_accuracy: 0.7692
# Epoch 90/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1721 - accuracy: 0.9482 - val_loss: 0.8693 - val_accuracy: 0.7692
# Epoch 91/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1468 - accuracy: 0.9442 - val_loss: 0.9096 - val_accuracy: 0.7692
# Epoch 92/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1338 - accuracy: 0.9681 - val_loss: 0.8898 - val_accuracy: 0.7846
# Epoch 93/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1566 - accuracy: 0.9641 - val_loss: 0.8581 - val_accuracy: 0.8000
# Epoch 94/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1874 - accuracy: 0.9402 - val_loss: 0.8409 - val_accuracy: 0.8000
# Epoch 95/100
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1766 - accuracy: 0.9402 - val_loss: 0.8415 - val_accuracy: 0.7846
# Epoch 96/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.2032 - accuracy: 0.9283 - val_loss: 0.8064 - val_accuracy: 0.7846
# Epoch 97/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1791 - accuracy: 0.9283 - val_loss: 0.8216 - val_accuracy: 0.7692
# Epoch 98/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1470 - accuracy: 0.9562 - val_loss: 0.8202 - val_accuracy: 0.7846
# Epoch 99/100
# 32/32 [==============================] - 1s 30ms/step - loss: 0.1357 - accuracy: 0.9641 - val_loss: 0.8228 - val_accuracy: 0.7846
# Epoch 100/100
# 32/32 [==============================] - 1s 31ms/step - loss: 0.1601 - accuracy: 0.9442 - val_loss: 0.8669 - val_accuracy: 0.8000

# %%
accs = H.history['accuracy']
val_accs = H.history['val_accuracy']

plt.plot(range(len(accs)),accs, label = 'Training_accuracy')
plt.plot(range(len(accs)),val_accs, label = 'Validation_accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend()
plt.show()

# %%
loss = H.history['loss']
val_loss = H.history['val_loss']

plt.plot(range(len(accs)),loss, label = 'Training_loss')
plt.plot(range(len(accs)),val_loss, label = 'Validation_loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()
plt.show()

# %%
# loss 와 정확도를 시각화
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on COVID-19 Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
# 테스트셋에서 예측값과 비교
print("[INFO] evaluating network...")
predIdxs = model.predict(testX, batch_size=BS)
# 테스트 세트의 각 이미지에 대해 우리는 대응하는 가장 큰 예측 확률을 가진 라벨의 인덱스를 찾아야 한다.
predIdxs = np.argmax(predIdxs, axis=1)
# classification 리포트 시각화
print(classification_report(testY.argmax(axis=1), predIdxs, target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f35e854bfde7> in <module>
#       5 predIdxs = np.argmax(predIdxs, axis=1)
#       6 # classification 리포트 시각화
# ----> 7 print(classification_report(testY.argmax(axis=1), predIdxs, target_names=lb.classes_))
#
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2018     else:
#    2019         longest_last_line_heading = 'weighted avg'
# -> 2020         name_width = max(len(cn) for cn in target_names)
#    2021         width = max(name_width, len(longest_last_line_heading), digits)
#    2022         head_fmt = '{:>{width}s} ' + ' {:>9}' * len(headers)
#
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py in <genexpr>(.0)
#    2018     else:
#    2019         longest_last_line_heading = 'weighted avg'
# -> 2020         name_width = max(len(cn) for cn in target_names)
#    2021         width = max(name_width, len(longest_last_line_heading), digits)
#    2022         head_fmt = '{:>{width}s} ' + ' {:>9}' * len(headers)
#
# TypeError: object of type 'numpy.int32' has no len()
